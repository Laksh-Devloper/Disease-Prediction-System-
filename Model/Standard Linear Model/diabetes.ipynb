# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\lakshya bhawsar\appdata\local\programs\python\python313\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\lakshya bhawsar\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lakshya bhawsar\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lakshya bhawsar\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lakshya bhawsar\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\lakshya bhawsar\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\lakshya bhawsar\appdata\local\programs\python\python313\lib\site-packages (1.6.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.19.5 in c:\users\lakshya bhawsar\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (2.2.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\lakshya bhawsar\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.15.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\lakshya bhawsar\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\lakshya bhawsar\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (3.5.0)

# %%
pip install xgboost
# Out:
# Collecting xgboost
#   Using cached xgboost-2.1.3-py3-none-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in c:\users\lakshya bhawsar\appdata\local\programs\python\python313\lib\site-packages (from xgboost) (2.2.2)
# Requirement already satisfied: scipy in c:\users\lakshya bhawsar\appdata\local\programs\python\python313\lib\site-packages (from xgboost) (1.15.1)
# Downloading xgboost-2.1.3-py3-none-win_amd64.whl (124.9 MB)
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.5/124.9 MB 3.5 MB/s eta 0:00:36
#    ---------------------------------------- 1.3/124.9 MB 3.6 MB/s eta 0:00:35
#     --------------------------------------- 1.6/124.9 MB 3.0 MB/s eta 0:00:42
#     --------------------------------------- 2.1/124.9 MB 2.6 MB/s eta 0:00:47
#     --------------------------------------- 2.6/124.9 MB 2.5 MB/s eta 0:00:49
#    - -------------------------------------- 3.1/124.9 MB 2.5 MB/s eta 0:00:50
#    - -------------------------------------- 3.7/124.9 MB 2.5 MB/s eta 0:00:50
#    - -------------------------------------- 4.2/124.9 MB 2.5 MB/s eta 0:00:49
#    - -------------------------------------- 4.7/124.9 MB 2.5 MB/s eta 0:00:49
#    - -------------------------------------- 5.2/124.9 MB 2.5 MB/s eta 0:00:48
#    - -------------------------------------- 6.0/124.9 MB 2.6 MB/s eta 0:00:46
#    -- ------------------------------------- 6.8/124.9 MB 2.7 MB/s eta 0:00:44
#    -- ------------------------------------- 7.9/124.9 MB 2.8 MB/s eta 0:00:42
#    -- ------------------------------------- 8.7/124.9 MB 2.9 MB/s eta 0:00:40
#    --- ------------------------------------ 9.4/124.9 MB 3.0 MB/s eta 0:00:39
#    --- ------------------------------------ 10.2/124.9 MB 3.1 MB/s eta 0:00:38
#    --- ------------------------------------ 11.0/124.9 MB 3.1 MB/s eta 0:00:37
#    --- ------------------------------------ 11.8/124.9 MB 3.1 MB/s eta 0:00:36
#    ---- ----------------------------------- 12.8/124.9 MB 3.2 MB/s eta 0:00:35
#    ---- ----------------------------------- 13.6/124.9 MB 3.2 MB/s eta 0:00:35
#    ---- ----------------------------------- 14.4/124.9 MB 3.3 MB/s eta 0:00:34
#    ---- ----------------------------------- 15.2/124.9 MB 3.3 MB/s eta 0:00:34
#    ----- ---------------------------------- 16.0/124.9 MB 3.3 MB/s eta 0:00:33
#    ----- ---------------------------------- 17.0/124.9 MB 3.4 MB/s eta 0:00:33
#    ----- ---------------------------------- 17.8/124.9 MB 3.4 MB/s eta 0:00:32
#    ----- ---------------------------------- 18.6/124.9 MB 3.4 MB/s eta 0:00:32
#    ------ --------------------------------- 19.4/124.9 MB 3.4 MB/s eta 0:00:31
#    ------ --------------------------------- 20.4/124.9 MB 3.4 MB/s eta 0:00:31
#    ------ --------------------------------- 21.2/124.9 MB 3.5 MB/s eta 0:00:30
#    ------- -------------------------------- 22.0/124.9 MB 3.5 MB/s eta 0:00:30
#    ------- -------------------------------- 22.8/124.9 MB 3.5 MB/s eta 0:00:30
#    ------- -------------------------------- 23.6/124.9 MB 3.5 MB/s eta 0:00:29
#    ------- -------------------------------- 24.4/124.9 MB 3.5 MB/s eta 0:00:29
#    -------- ------------------------------- 25.4/124.9 MB 3.5 MB/s eta 0:00:29
#    -------- ------------------------------- 26.2/124.9 MB 3.5 MB/s eta 0:00:28
#    -------- ------------------------------- 27.0/124.9 MB 3.6 MB/s eta 0:00:28
#    -------- ------------------------------- 27.8/124.9 MB 3.6 MB/s eta 0:00:28
#    --------- ------------------------------ 28.6/124.9 MB 3.6 MB/s eta 0:00:27
#    --------- ------------------------------ 29.6/124.9 MB 3.6 MB/s eta 0:00:27
#    --------- ------------------------------ 30.4/124.9 MB 3.6 MB/s eta 0:00:27
#    --------- ------------------------------ 31.2/124.9 MB 3.6 MB/s eta 0:00:27
#    ---------- ----------------------------- 32.0/124.9 MB 3.6 MB/s eta 0:00:26
#    ---------- ----------------------------- 32.8/124.9 MB 3.6 MB/s eta 0:00:26
#    ---------- ----------------------------- 33.8/124.9 MB 3.6 MB/s eta 0:00:26
#    ----------- ---------------------------- 34.6/124.9 MB 3.6 MB/s eta 0:00:25
#    ----------- ---------------------------- 35.4/124.9 MB 3.6 MB/s eta 0:00:25
#    ----------- ---------------------------- 36.2/124.9 MB 3.6 MB/s eta 0:00:25
#    ----------- ---------------------------- 37.0/124.9 MB 3.7 MB/s eta 0:00:25
#    ------------ --------------------------- 38.0/124.9 MB 3.7 MB/s eta 0:00:24
#    ------------ --------------------------- 38.8/124.9 MB 3.7 MB/s eta 0:00:24
#    ------------ --------------------------- 39.6/124.9 MB 3.7 MB/s eta 0:00:24
#    ------------ --------------------------- 40.4/124.9 MB 3.7 MB/s eta 0:00:24
#    ------------- -------------------------- 41.2/124.9 MB 3.7 MB/s eta 0:00:23
#    ------------- -------------------------- 42.2/124.9 MB 3.7 MB/s eta 0:00:23
#    ------------- -------------------------- 43.0/124.9 MB 3.7 MB/s eta 0:00:23
#    -------------- ------------------------- 43.8/124.9 MB 3.7 MB/s eta 0:00:22
#    -------------- ------------------------- 44.6/124.9 MB 3.7 MB/s eta 0:00:22
#    -------------- ------------------------- 45.4/124.9 MB 3.7 MB/s eta 0:00:22
#    -------------- ------------------------- 46.1/124.9 MB 3.7 MB/s eta 0:00:22
#    --------------- ------------------------ 47.2/124.9 MB 3.7 MB/s eta 0:00:21
#    --------------- ------------------------ 48.0/124.9 MB 3.7 MB/s eta 0:00:21
#    --------------- ------------------------ 48.8/124.9 MB 3.7 MB/s eta 0:00:21
#    --------------- ------------------------ 49.5/124.9 MB 3.7 MB/s eta 0:00:21
#    ---------------- ----------------------- 50.3/124.9 MB 3.7 MB/s eta 0:00:21
#    ---------------- ----------------------- 51.4/124.9 MB 3.7 MB/s eta 0:00:20
#    ---------------- ----------------------- 52.2/124.9 MB 3.7 MB/s eta 0:00:20
#    ---------------- ----------------------- 53.0/124.9 MB 3.7 MB/s eta 0:00:20
#    ----------------- ---------------------- 53.7/124.9 MB 3.7 MB/s eta 0:00:20
#    ----------------- ---------------------- 54.5/124.9 MB 3.7 MB/s eta 0:00:19
#    ----------------- ---------------------- 55.6/124.9 MB 3.7 MB/s eta 0:00:19
#    ------------------ --------------------- 56.4/124.9 MB 3.7 MB/s eta 0:00:19
#    ------------------ --------------------- 57.1/124.9 MB 3.7 MB/s eta 0:00:19
#    ------------------ --------------------- 57.9/124.9 MB 3.8 MB/s eta 0:00:18
#    ------------------ --------------------- 58.7/124.9 MB 3.8 MB/s eta 0:00:18
#    ------------------- -------------------- 59.8/124.9 MB 3.8 MB/s eta 0:00:18
#    ------------------- -------------------- 60.6/124.9 MB 3.8 MB/s eta 0:00:18
#    ------------------- -------------------- 61.3/124.9 MB 3.8 MB/s eta 0:00:17
#    ------------------- -------------------- 62.1/124.9 MB 3.8 MB/s eta 0:00:17
#    -------------------- ------------------- 62.9/124.9 MB 3.8 MB/s eta 0:00:17
#    -------------------- ------------------- 64.0/124.9 MB 3.8 MB/s eta 0:00:17
#    -------------------- ------------------- 64.7/124.9 MB 3.8 MB/s eta 0:00:16
#    -------------------- ------------------- 65.5/124.9 MB 3.8 MB/s eta 0:00:16
#    --------------------- ------------------ 66.3/124.9 MB 3.8 MB/s eta 0:00:16
#    --------------------- ------------------ 67.1/124.9 MB 3.8 MB/s eta 0:00:16
#    --------------------- ------------------ 67.9/124.9 MB 3.8 MB/s eta 0:00:16
#    ---------------------- ----------------- 68.9/124.9 MB 3.8 MB/s eta 0:00:15
#    ---------------------- ----------------- 69.7/124.9 MB 3.8 MB/s eta 0:00:15
#    ---------------------- ----------------- 70.5/124.9 MB 3.8 MB/s eta 0:00:15
#    ---------------------- ----------------- 71.3/124.9 MB 3.8 MB/s eta 0:00:15
#    ----------------------- ---------------- 72.1/124.9 MB 3.8 MB/s eta 0:00:14
#    ----------------------- ---------------- 73.1/124.9 MB 3.8 MB/s eta 0:00:14
#    ----------------------- ---------------- 73.9/124.9 MB 3.8 MB/s eta 0:00:14
#    ----------------------- ---------------- 74.7/124.9 MB 3.8 MB/s eta 0:00:14
#    ------------------------ --------------- 75.5/124.9 MB 3.8 MB/s eta 0:00:14
#    ------------------------ --------------- 76.5/124.9 MB 3.8 MB/s eta 0:00:13
#    ------------------------ --------------- 77.1/124.9 MB 3.8 MB/s eta 0:00:13
#    ------------------------- -------------- 78.1/124.9 MB 3.8 MB/s eta 0:00:13
#    ------------------------- -------------- 78.9/124.9 MB 3.8 MB/s eta 0:00:13
#    ------------------------- -------------- 79.7/124.9 MB 3.8 MB/s eta 0:00:12
#    ------------------------- -------------- 80.5/124.9 MB 3.8 MB/s eta 0:00:12
#    -------------------------- ------------- 81.5/124.9 MB 3.8 MB/s eta 0:00:12
#    -------------------------- ------------- 82.3/124.9 MB 3.8 MB/s eta 0:00:12
#    -------------------------- ------------- 83.1/124.9 MB 3.8 MB/s eta 0:00:11
#    -------------------------- ------------- 83.9/124.9 MB 3.8 MB/s eta 0:00:11
#    --------------------------- ------------ 84.7/124.9 MB 3.8 MB/s eta 0:00:11
#    --------------------------- ------------ 85.7/124.9 MB 3.8 MB/s eta 0:00:11
#    --------------------------- ------------ 86.5/124.9 MB 3.8 MB/s eta 0:00:11
#    --------------------------- ------------ 87.3/124.9 MB 3.8 MB/s eta 0:00:10
#    ---------------------------- ----------- 88.1/124.9 MB 3.8 MB/s eta 0:00:10
#    ---------------------------- ----------- 88.9/124.9 MB 3.8 MB/s eta 0:00:10
#    ---------------------------- ----------- 89.9/124.9 MB 3.8 MB/s eta 0:00:10
#    ----------------------------- ---------- 90.7/124.9 MB 3.8 MB/s eta 0:00:09
#    ----------------------------- ---------- 91.5/124.9 MB 3.8 MB/s eta 0:00:09
#    ----------------------------- ---------- 92.3/124.9 MB 3.8 MB/s eta 0:00:09
#    ----------------------------- ---------- 93.1/124.9 MB 3.8 MB/s eta 0:00:09
#    ------------------------------ --------- 94.1/124.9 MB 3.8 MB/s eta 0:00:09
#    ------------------------------ --------- 94.9/124.9 MB 3.8 MB/s eta 0:00:08
#    ------------------------------ --------- 95.7/124.9 MB 3.8 MB/s eta 0:00:08
#    ------------------------------ --------- 96.5/124.9 MB 3.8 MB/s eta 0:00:08
#    ------------------------------- -------- 97.3/124.9 MB 3.8 MB/s eta 0:00:08
#    ------------------------------- -------- 98.3/124.9 MB 3.8 MB/s eta 0:00:07
#    ------------------------------- -------- 99.1/124.9 MB 3.8 MB/s eta 0:00:07
#    ------------------------------- -------- 99.9/124.9 MB 3.8 MB/s eta 0:00:07
#    -------------------------------- ------- 100.7/124.9 MB 3.8 MB/s eta 0:00:07
#    -------------------------------- ------- 101.4/124.9 MB 3.8 MB/s eta 0:00:07
#    -------------------------------- ------- 102.5/124.9 MB 3.8 MB/s eta 0:00:06
#    --------------------------------- ------ 103.3/124.9 MB 3.8 MB/s eta 0:00:06
#    --------------------------------- ------ 104.1/124.9 MB 3.8 MB/s eta 0:00:06
#    --------------------------------- ------ 104.9/124.9 MB 3.8 MB/s eta 0:00:06
#    --------------------------------- ------ 105.6/124.9 MB 3.8 MB/s eta 0:00:06
#    ---------------------------------- ----- 106.7/124.9 MB 3.8 MB/s eta 0:00:05
#    ---------------------------------- ----- 107.5/124.9 MB 3.8 MB/s eta 0:00:05
#    ---------------------------------- ----- 108.3/124.9 MB 3.8 MB/s eta 0:00:05
#    ---------------------------------- ----- 109.1/124.9 MB 3.8 MB/s eta 0:00:05
#    ----------------------------------- ---- 109.8/124.9 MB 3.8 MB/s eta 0:00:04
#    ----------------------------------- ---- 110.9/124.9 MB 3.8 MB/s eta 0:00:04
#    ----------------------------------- ---- 111.7/124.9 MB 3.8 MB/s eta 0:00:04
#    ------------------------------------ --- 112.5/124.9 MB 3.8 MB/s eta 0:00:04
#    ------------------------------------ --- 113.2/124.9 MB 3.8 MB/s eta 0:00:04
#    ------------------------------------ --- 114.0/124.9 MB 3.8 MB/s eta 0:00:03
#    ------------------------------------ --- 115.1/124.9 MB 3.8 MB/s eta 0:00:03
#    ------------------------------------- -- 115.9/124.9 MB 3.8 MB/s eta 0:00:03
#    ------------------------------------- -- 116.7/124.9 MB 3.8 MB/s eta 0:00:03
#    ------------------------------------- -- 117.4/124.9 MB 3.9 MB/s eta 0:00:02
#    ------------------------------------- -- 118.2/124.9 MB 3.9 MB/s eta 0:00:02
#    -------------------------------------- - 119.3/124.9 MB 3.9 MB/s eta 0:00:02
#    -------------------------------------- - 120.1/124.9 MB 3.9 MB/s eta 0:00:02
#    -------------------------------------- - 120.8/124.9 MB 3.9 MB/s eta 0:00:02
#    -------------------------------------- - 121.6/124.9 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  122.4/124.9 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  123.5/124.9 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  124.3/124.9 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  124.8/124.9 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  124.8/124.9 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 124.9/124.9 MB 3.9 MB/s eta 0:00:00
# Installing collected packages: xgboost
# Successfully installed xgboost-2.1.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix

# %%
diabetes_dataset = pd.read_csv("M:\\Techsaksham_by_Microsoft_Project\\Project\\dataset\\diabetes.csv")

# %%
diabetes_dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes_dataset.shape
# Out:
# (768, 9)

# %%
diabetes_dataset.describe
# Out:
# <bound method NDFrame.describe of      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]>

# %%
diabetes_dataset['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %% [markdown]
# The Below mean cell , finds average of alll the outcomes like in outcome 0 the pregnancies avg is 3.29

# %%
diabetes_dataset.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %%
X = diabetes_dataset.drop(columns=['Outcome'],axis=1)
Y = diabetes_dataset['Outcome']

# %%
X.head
# Out:
# <bound method NDFrame.head of      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   32
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# 763                     0.171   63
# 764                     0.340   27
# 765                     0.245   30
# 766                     0.349   47
# 767                     0.315   23
#
# [768 rows x 8 columns]>

# %%
X_train, X_test, Y_train, Y_test =train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
X_train.head()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 60             2       84              0              0        0   0.0
# 618            9      112             82             24        0  28.2
# 346            1      139             46             19       83  28.7
# 294            0      161             50              0        0  21.9
# 231            6      134             80             37      370  46.2
#
#      DiabetesPedigreeFunction  Age
# 60                      0.304   21
# 618                     1.282   50
# 346                     0.654   22
# 294                     0.254   65
# 231                     0.238   46

# %%
model = svm.SVC(kernel='linear')
# Out:
# XGBoost Accuracy: 0.7077922077922078
# c:\Users\Lakshya Bhawsar\AppData\Local\Programs\Python\Python313\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:40:49] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %%
model.fit(X_train,Y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred = model.predict(X_test)

# %%
# Confusion Matrix
cm = confusion_matrix(Y_test, y_pred)

print("Confusion Matrix :- \n" , cm)
# Out:
# Confusion Matrix :-
#  [[80 19]
#  [19 36]]

# %%
# Precision Score
precision = precision_score(Y_test, y_pred)  
print("Precision:", precision)

# Recall
recall = recall_score(Y_test, y_pred) 
print("Recall:", recall)

# F1-Score 
f1 = f1_score(Y_test, y_pred)
print("F1-Score:", f1)
# Out:
# Precision: 0.6545454545454545
# Recall: 0.6545454545454545
# F1-Score: 0.6545454545454545

# %%
print(accuracy_score(Y_test,y_pred))
# Out:
# 0.7532467532467533

# %%
pip install pickle
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement pickle (from versions: none)
# ERROR: No matching distribution found for pickle

# %%
import pickle
filename = 'diabetes_model.sav'
pickle.dump(model, open(filename, 'wb'))

# %%
inputarr = [4 , 53 , 764, 42, 53, 58 , 55 ,563]
innumpyarr = np.asarray(inputarr)
reshapearr = innumpyarr.reshape(1 , -1)

pred = model.predict(reshapearr)
print(pred)

if pred[0] == 0:
    print("the Person is not diabetic")
elif pred[0] == 1:
    print("The Person is Diabetic")
# Out:
# [1]
# The Person is Diabetic
# c:\Users\Lakshya Bhawsar\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
# Loads the model saved above using pickle 
loaded_model = pickle.load(open('diabetes_model.sav' , 'rb'))

#Predicts the input data from the model saved
loaded_model.predict(reshapearr)
print(pred)

if pred[0] == 0:
    print("the Person is not diabetic")
elif pred[0] == 1:
    print("The Person is Diabetic")
# Out:
# [1]
# The Person is Diabetic
# c:\Users\Lakshya Bhawsar\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
